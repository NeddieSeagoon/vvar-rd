# %%
import pandas as pd
import numpy as np
from scipy.stats import ks_2samp
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
titan = pd.read_csv('../data/radar-size-mult/titan.csv')
pisces = pd.read_csv('../data/radar-size-mult/pisces.csv')
hulla = pd.read_csv('../data/radar-size-mult/hull-a.csv')

# %%
def scale_df(df, scalar):
    columns = df.columns
    scaled_data = scaler.fit_transform(df.to_numpy())
    scaled_df = pd.DataFrame(scaled_data, columns=columns)
    return scaled_df

# %%
titan.plot()
pisces.plot()
hulla.plot()
# Out:
# <AxesSubplot: >
